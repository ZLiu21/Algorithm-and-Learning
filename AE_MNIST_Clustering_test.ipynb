# %%
import numpy as np
import torch
import torch.nn as nn
from torch.optim import Adam
import torch.nn.functional as F
from torch.nn import Linear
from sklearn.cluster import KMeans
"""
原文链接：IDEC,https://www.ijcai.org/proceedings/2017/0243.pdf
Pytorch版复现代码链接：https://github.com/dawnranger/IDEC-pytorch
"""

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '1'
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# /home/lz/anaconda3/lib/python3.6/site-packages/torch/cuda/__init__.py:52: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 10000). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at  /pytorch/c10/cuda/CUDAFunctions.cpp:109.)
#   return torch._C._cuda_getDeviceCount() > 0

# %%
def RI_metric(pred, target):
    # RI
    n = len(target)
    TP = 0
    TN = 0
    for i in range(n - 1):
        for j in range(i + 1, n):
            if target[i] != target[j]:
                if pred[i] != pred[j]:
                    TN += 1
            else:
                if pred[i] == pred[j]:
                    TP += 1

    RI = n * (n - 1) / 2
    RI = (TP + TN) / RI
    return RI


def cluster_acc(y_true, y_pred):
    """
    Calculate clustering accuracy. Require scikit-learn installed

    # Arguments
        y: true labels, numpy.array with shape `(n_samples,)`
        y_pred: predicted labels, numpy.array with shape `(n_samples,)`

    # Return
        accuracy, in [0,1]
    """
    y_true = y_true.astype(np.int64)
    assert y_pred.size == y_true.size
    D = max(y_pred.max(), y_true.max()) + 1
    w = np.zeros((D, D), dtype=np.int64)
    for i in range(y_pred.size):
        w[y_pred[i], y_true[i]] += 1
    # from sklearn.utils.linear_assignment_ import linear_assignment
    from scipy.optimize import linear_sum_assignment as linear_assignment
    ind = linear_assignment(w.max() - w)
    ind = np.asarray(ind)
    ind = np.transpose(ind)
    return sum([w[i, j] for i, j in ind]) * 1.0 / y_pred.size


def AccRIkeans(data, num_class, real_label) -> float:
    data = data.copy()
    data[np.isnan(data)] = 0
    kmeans = KMeans(n_clusters=num_class, n_init=20)
    kmeans.fit(data)
    label_bank = kmeans.labels_
    RI_kmeans = RI_metric(pred=label_bank, target=real_label)
    acc_kmeans = cluster_acc(y_true=real_label, y_pred=label_bank)
    return round(RI_kmeans, 4), round(acc_kmeans, 4)

# %%
def next_batch(samples_num, batch = 256):
    batch_num = int(samples_num / batch)
    left_row = samples_num - batch_num * batch

    for i in range(batch_num):
        yield np.arange(i * batch, (i + 1) * batch)

    if left_row != 0:
        yield np.arange(samples_num - left_row, samples_num)

# %%
class AE(nn.Module):

    def __init__(self, n_enc_1, n_enc_2, n_enc_3, n_dec_1, n_dec_2, n_dec_3,
                 n_input, n_z):
        super(AE, self).__init__()

        # encoder
        self.enc_1 = Linear(n_input, n_enc_1)
        self.enc_2 = Linear(n_enc_1, n_enc_2)
        self.enc_3 = Linear(n_enc_2, n_enc_3)

        self.z_layer = Linear(n_enc_3, n_z)

        # decoder
        self.dec_1 = Linear(n_z, n_dec_1)
        self.dec_2 = Linear(n_dec_1, n_dec_2)
        self.dec_3 = Linear(n_dec_2, n_dec_3)

        self.x_bar_layer = Linear(n_dec_3, n_input)

    def forward(self, x):
        # encoder
        enc_h1 = F.relu(self.enc_1(x))
        enc_h2 = F.relu(self.enc_2(enc_h1))
        enc_h3 = F.relu(self.enc_3(enc_h2))

        z = self.z_layer(enc_h3)

        # decoder
        dec_h1 = F.relu(self.dec_1(z))
        dec_h2 = F.relu(self.dec_2(dec_h1))
        dec_h3 = F.relu(self.dec_3(dec_h2))
        x_bar = self.x_bar_layer(dec_h3)

        return x_bar, z

# %%
def model_ae_cluster(X, Y):
    print("Start: ", X.shape, Y.shape)
    for i in range(10):
        temp = np.where(Y == i)[0]
        print("The number of ", i, " = ", len(temp))
    feature_dim = 28 * 28
    model = AE(
        n_enc_1=500,
        n_enc_2=500,
        n_enc_3=2000,
        n_dec_1=2000,
        n_dec_2=500,
        n_dec_3=500,
        n_input=feature_dim,
        n_z=10)
    print(model)
    model= model.to(device)
    optimizer = Adam(model.parameters(), lr=0.001)
    ae_representation = []
    max_acc = 0.0
    max_ri = 0.0

    for epoch in range(201):
        total_loss = 0.0
        count_batch = 0
        representation = []
        for idxs in next_batch(X.shape[0]):
            x1 = torch.tensor(X[idxs]).clone()
            x1 = x1.to(device)
            optimizer.zero_grad()
            x_bar, z = model(x1)
            loss = F.mse_loss(x_bar, x1)
            total_loss = total_loss + loss.item()
            loss.backward()
            optimizer.step()
            count_batch = count_batch + 1
            representation.append(z.data.cpu().numpy())

        representation = np.concatenate(representation)
        ae_representation = representation
        if epoch % 1 == 0:
            print("epoch {} loss={:.4f}".format(epoch, total_loss / count_batch))
        if epoch % 10 == 0:
            representation_RI, representation_Acc = AccRIkeans(
                data=ae_representation, num_class=10, real_label=Y)
            max_acc = max(representation_Acc, max_acc)
            max_ri = max(representation_RI, max_ri)
            print("epoch = ", epoch,
                  ", representation RI_kmeans = ", representation_RI, ", representation_Acc_kmeans = ", representation_Acc)

    print("*"*30)
    print("max_acc = ", max_acc)
    print("max_ri = ", max_ri)
    print("End training of AE.")
    temp_X = torch.tensor(X).to(device)
    _, hidden_x = model(temp_X)
    hidden_RI, hidden_Acc = AccRIkeans(data=hidden_x.data.cpu().numpy(), num_class=10, real_label=Y)
    print("hidden_RI = ", hidden_RI, ", hidden_Acc = ", hidden_Acc)
    Row_RI, Row_Acc = AccRIkeans(data=X, num_class=10, real_label=Y)
    print("Row_RI = ", Row_RI, ", Row_Acc = ", Row_Acc)
    return model

# %%
def load_mnist(path='./dataset/mnist.npz'):
    f = np.load(path)

    x_train, y_train, x_test, y_test = f['x_train'], f['y_train'], f[
        'x_test'], f['y_test']
    f.close()
    x = np.concatenate((x_train, x_test))
    y = np.concatenate((y_train, y_test)).astype(np.int32)
    x = x.reshape((x.shape[0], -1)).astype(np.float32)
    x = np.divide(x, 255.)
    print('MNIST samples', x.shape)
    return x, y

# %%
x, y = load_mnist()
print(x.shape, y.shape)
# Out:
# MNIST samples (70000, 784)
# (70000, 784) (70000,)

# %%
model_all = model_ae_cluster(X=x, Y=y)
# Out:
# Start:  (70000, 784) (70000,)
# The number of  0  =  6903
# The number of  1  =  7877
# The number of  2  =  6990
# The number of  3  =  7141
# The number of  4  =  6824
# The number of  5  =  6313
# The number of  6  =  6876
# The number of  7  =  7293
# The number of  8  =  6825
# The number of  9  =  6958
# AE(
#   (enc_1): Linear(in_features=784, out_features=500, bias=True)
#   (enc_2): Linear(in_features=500, out_features=500, bias=True)
#   (enc_3): Linear(in_features=500, out_features=2000, bias=True)
#   (z_layer): Linear(in_features=2000, out_features=10, bias=True)
#   (dec_1): Linear(in_features=10, out_features=2000, bias=True)
#   (dec_2): Linear(in_features=2000, out_features=500, bias=True)
#   (dec_3): Linear(in_features=500, out_features=500, bias=True)
#   (x_bar_layer): Linear(in_features=500, out_features=784, bias=True)
# )
# epoch 0 loss=0.0561
# epoch =  0 , representation RI_kmeans =  0.7949 , representation_Acc_kmeans =  0.2782
# epoch 155 loss=0.0103
# epoch 156 loss=0.0104
# epoch 157 loss=0.0105
# epoch 158 loss=0.0104
# epoch 159 loss=0.0104
# epoch 160 loss=0.0105
# epoch =  160 , representation RI_kmeans =  0.9302 , representation_Acc_kmeans =  0.7479
# epoch 161 loss=0.0104
# epoch 162 loss=0.0103
# epoch 163 loss=0.0101
# epoch 164 loss=0.0100
# epoch 165 loss=0.0100
# epoch 166 loss=0.0099
# epoch 167 loss=0.0099
# epoch 168 loss=0.0099
# epoch 169 loss=0.0100
# epoch 170 loss=0.0101
# epoch =  170 , representation RI_kmeans =  0.93 , representation_Acc_kmeans =  0.7476
# epoch 171 loss=0.0104
# epoch 172 loss=0.0107
# epoch 173 loss=0.0108
# epoch 174 loss=0.0105
# epoch 175 loss=0.0103
# epoch 176 loss=0.0101
# epoch 177 loss=0.0099
# epoch 178 loss=0.0098
# epoch 179 loss=0.0097
# epoch 180 loss=0.0096
# epoch =  180 , representation RI_kmeans =  0.9216 , representation_Acc_kmeans =  0.7152
# epoch 181 loss=0.0096
# epoch 182 loss=0.0096
# epoch 183 loss=0.0096
# epoch 184 loss=0.0096
# epoch 185 loss=0.0096
# epoch 186 loss=0.0096
# epoch 187 loss=0.0097
# epoch 188 loss=0.0097
# epoch 189 loss=0.0098
# epoch 190 loss=0.0099
# epoch =  190 , representation RI_kmeans =  0.9249 , representation_Acc_kmeans =  0.7268
# epoch 191 loss=0.0099
# epoch 192 loss=0.0098
# epoch 193 loss=0.0098
# epoch 194 loss=0.0097
# epoch 195 loss=0.0098
# epoch 196 loss=0.0098
# epoch 197 loss=0.0099
# epoch 198 loss=0.0099
# epoch 199 loss=0.0100
# epoch 200 loss=0.0100
# epoch =  200 , representation RI_kmeans =  0.925 , representation_Acc_kmeans =  0.7263
# ******************************
# max_acc =  0.7625
# max_ri =  0.9321
# End training of AE.
# hidden_RI =  0.9264 , hidden_Acc =  0.7323
# Row_RI =  0.8818 , Row_Acc =  0.5324

# %%
temp_X = torch.tensor(x[:6000]).to(device)
_, hidden_x = model_all(temp_X)
hidden_RI, hidden_Acc = AccRIkeans(data=hidden_x.data.cpu().numpy(), num_class=10, real_label=y[:6000])
print("hidden_RI = ", hidden_RI, ", hidden_Acc = ", hidden_Acc)
# Out:
# hidden_RI =  0.9327 , hidden_Acc =  0.7843

# %%
model_half = model_ae_cluster(X=x[:30000], Y=y[:30000])
# Out:
# Start:  (30000, 784) (30000,)
# The number of  0  =  2961
# The number of  1  =  3423
# The number of  2  =  2948
# The number of  3  =  3073
# The number of  4  =  2926
# The number of  5  =  2709
# The number of  6  =  2975
# The number of  7  =  3107
# The number of  8  =  2875
# The number of  9  =  3003
# AE(
#   (enc_1): Linear(in_features=784, out_features=500, bias=True)
#   (enc_2): Linear(in_features=500, out_features=500, bias=True)
#   (enc_3): Linear(in_features=500, out_features=2000, bias=True)
#   (z_layer): Linear(in_features=2000, out_features=10, bias=True)
#   (dec_1): Linear(in_features=10, out_features=2000, bias=True)
#   (dec_2): Linear(in_features=2000, out_features=500, bias=True)
#   (dec_3): Linear(in_features=500, out_features=500, bias=True)
#   (x_bar_layer): Linear(in_features=500, out_features=784, bias=True)
# )
# epoch 0 loss=0.0643
# epoch =  0 , representation RI_kmeans =  0.7787 , representation_Acc_kmeans =  0.1734
# epoch 1 loss=0.0516
# epoch 2 loss=0.0390
# epoch 3 loss=0.0314
# epoch 4 loss=0.0276
# epoch 5 loss=0.0250
# epoch 6 loss=0.0233
# epoch 7 loss=0.0218
# epoch 8 loss=0.0206
# epoch 9 loss=0.0198
# epoch 10 loss=0.0194
# epoch =  10 , representation RI_kmeans =  0.9044 , representation_Acc_kmeans =  0.6604
# epoch 11 loss=0.0187
# epoch 12 loss=0.0182
# epoch 13 loss=0.0179
# epoch 14 loss=0.0176
# epoch 15 loss=0.0172
# epoch 16 loss=0.0168
# epoch 17 loss=0.0166
# epoch 18 loss=0.0166
# epoch 19 loss=0.0165
# epoch 20 loss=0.0163
# epoch =  20 , representation RI_kmeans =  0.9078 , representation_Acc_kmeans =  0.6907
# epoch 21 loss=0.0159
# epoch 22 loss=0.0157
# epoch 23 loss=0.0156
# epoch 24 loss=0.0154
# epoch 25 loss=0.0153
# epoch 26 loss=0.0152
# epoch 27 loss=0.0151
# epoch 28 loss=0.0150
# epoch 29 loss=0.0151
# epoch 30 loss=0.0151
# epoch =  30 , representation RI_kmeans =  0.9147 , representation_Acc_kmeans =  0.7141
# epoch 31 loss=0.0150
# epoch 32 loss=0.0148
# epoch 33 loss=0.0145
# epoch 34 loss=0.0143
# epoch 35 loss=0.0142
# epoch 36 loss=0.0142
# epoch 37 loss=0.0142
# epoch 38 loss=0.0144
# epoch 39 loss=0.0144
# epoch 40 loss=0.0141
# epoch =  40 , representation RI_kmeans =  0.9149 , representation_Acc_kmeans =  0.7164
# epoch 41 loss=0.0139
# epoch 42 loss=0.0139
# epoch 43 loss=0.0139
# epoch 44 loss=0.0139
# epoch 45 loss=0.0140
# epoch 46 loss=0.0139
# epoch 47 loss=0.0139
# epoch 48 loss=0.0140
# epoch 49 loss=0.0141
# epoch 50 loss=0.0140
# epoch =  50 , representation RI_kmeans =  0.9107 , representation_Acc_kmeans =  0.7051
# epoch 51 loss=0.0140
# epoch 52 loss=0.0139
# epoch 53 loss=0.0135
# epoch 54 loss=0.0132
# epoch 55 loss=0.0131
# epoch 56 loss=0.0131
# epoch 57 loss=0.0132
# epoch 58 loss=0.0131
# epoch 59 loss=0.0131
# epoch 60 loss=0.0131
# epoch =  60 , representation RI_kmeans =  0.9115 , representation_Acc_kmeans =  0.7141
# epoch 61 loss=0.0132
# epoch 62 loss=0.0134
# epoch 63 loss=0.0135
# epoch 64 loss=0.0133
# epoch 65 loss=0.0131
# epoch 66 loss=0.0130
# epoch 67 loss=0.0129
# epoch 68 loss=0.0129
# epoch 69 loss=0.0130
# epoch 70 loss=0.0130
# epoch 147 loss=0.0117
# epoch 148 loss=0.0116
# epoch 149 loss=0.0116
# epoch 150 loss=0.0116
# epoch =  150 , representation RI_kmeans =  0.8922 , representation_Acc_kmeans =  0.6096
# epoch 151 loss=0.0115
# epoch 152 loss=0.0116
# epoch 153 loss=0.0116
# epoch 154 loss=0.0118
# epoch 155 loss=0.0119
# epoch 156 loss=0.0120
# epoch 157 loss=0.0120
# epoch 158 loss=0.0120
# epoch 159 loss=0.0119
# epoch 160 loss=0.0117
# epoch =  160 , representation RI_kmeans =  0.8901 , representation_Acc_kmeans =  0.6071
# epoch 161 loss=0.0115
# epoch 162 loss=0.0115
# epoch 163 loss=0.0114
# epoch 164 loss=0.0114
# epoch 165 loss=0.0114
# epoch 166 loss=0.0114
# epoch 167 loss=0.0115
# epoch 168 loss=0.0117
# epoch 169 loss=0.0118
# epoch 170 loss=0.0118
# epoch =  170 , representation RI_kmeans =  0.8907 , representation_Acc_kmeans =  0.6063
# epoch 171 loss=0.0117
# epoch 172 loss=0.0115
# epoch 173 loss=0.0114
# epoch 174 loss=0.0115
# epoch 175 loss=0.0116
# epoch 176 loss=0.0119
# epoch 177 loss=0.0120
# epoch 178 loss=0.0118
# epoch 179 loss=0.0115
# epoch 180 loss=0.0112
# epoch =  180 , representation RI_kmeans =  0.8877 , representation_Acc_kmeans =  0.6031
# epoch 181 loss=0.0111
# epoch 182 loss=0.0111
# epoch 183 loss=0.0112
# epoch 184 loss=0.0113
# epoch 185 loss=0.0114
# epoch 186 loss=0.0115
# epoch 187 loss=0.0115
# epoch 188 loss=0.0114
# epoch 189 loss=0.0112
# epoch 190 loss=0.0111
# epoch =  190 , representation RI_kmeans =  0.89 , representation_Acc_kmeans =  0.6094
# epoch 191 loss=0.0109
# epoch 192 loss=0.0108
# epoch 193 loss=0.0108
# epoch 194 loss=0.0109
# epoch 195 loss=0.0111
# epoch 196 loss=0.0112
# epoch 197 loss=0.0113
# epoch 198 loss=0.0112
# epoch 199 loss=0.0112
# epoch 200 loss=0.0112
# epoch =  200 , representation RI_kmeans =  0.8903 , representation_Acc_kmeans =  0.6098
# ******************************
# max_acc =  0.7164
# max_ri =  0.9149
# End training of AE.
# hidden_RI =  0.8891 , hidden_Acc =  0.594
# Row_RI =  0.8819 , Row_Acc =  0.529

# %%
temp_X = torch.tensor(x[:6000]).to(device)
_, hidden_x = model_half(temp_X)
hidden_RI, hidden_Acc = AccRIkeans(data=hidden_x.data.cpu().numpy(), num_class=10, real_label=y[:6000])
print("hidden_RI = ", hidden_RI, ", hidden_Acc = ", hidden_Acc)
# Out:
# hidden_RI =  0.8918 , hidden_Acc =  0.6107

# %%
model_part = model_ae_cluster(X=x[:12000], Y=y[:12000])
# Out:
# Start:  (12000, 784) (12000,)
# The number of  0  =  1206
# The number of  1  =  1351
# The number of  2  =  1176
# The number of  3  =  1228
# The number of  4  =  1184
# The number of  5  =  1048
# The number of  6  =  1208
# The number of  7  =  1279
# The number of  8  =  1127
# The number of  9  =  1193
# AE(
#   (enc_1): Linear(in_features=784, out_features=500, bias=True)
#   (enc_2): Linear(in_features=500, out_features=500, bias=True)
#   (enc_3): Linear(in_features=500, out_features=2000, bias=True)
#   (z_layer): Linear(in_features=2000, out_features=10, bias=True)
#   (dec_1): Linear(in_features=10, out_features=2000, bias=True)
#   (dec_2): Linear(in_features=2000, out_features=500, bias=True)
#   (dec_3): Linear(in_features=500, out_features=500, bias=True)
#   (x_bar_layer): Linear(in_features=500, out_features=784, bias=True)
# )
# epoch 0 loss=0.0707
# epoch =  0 , representation RI_kmeans =  0.7138 , representation_Acc_kmeans =  0.155
# epoch 1 loss=0.0617
# epoch 2 loss=0.0568
# epoch 3 loss=0.0510
# epoch 4 loss=0.0449
# epoch 5 loss=0.0391
# epoch 6 loss=0.0339
# epoch 7 loss=0.0311
# epoch 8 loss=0.0295
# epoch 9 loss=0.0282
# epoch 10 loss=0.0273
# epoch =  10 , representation RI_kmeans =  0.8881 , representation_Acc_kmeans =  0.5693
# epoch 11 loss=0.0267
# epoch 12 loss=0.0260
# epoch 13 loss=0.0249
# epoch 14 loss=0.0240
# epoch 15 loss=0.0234
# epoch 16 loss=0.0228
# epoch 17 loss=0.0222
# epoch 18 loss=0.0216
# epoch 19 loss=0.0213
# epoch 20 loss=0.0210
# epoch =  20 , representation RI_kmeans =  0.8868 , representation_Acc_kmeans =  0.568
# epoch 21 loss=0.0209
# epoch 22 loss=0.0208
# epoch 23 loss=0.0203
# epoch 24 loss=0.0198
# epoch 25 loss=0.0195
# epoch 26 loss=0.0196
# epoch 27 loss=0.0194
# epoch 28 loss=0.0190
# epoch 29 loss=0.0187
# epoch 30 loss=0.0185
# epoch =  30 , representation RI_kmeans =  0.8866 , representation_Acc_kmeans =  0.5521
# epoch 31 loss=0.0184
# epoch 32 loss=0.0183
# epoch 33 loss=0.0183
# epoch 34 loss=0.0179
# epoch 35 loss=0.0177
# epoch 36 loss=0.0176
# epoch 37 loss=0.0175
# epoch 38 loss=0.0176
# epoch 39 loss=0.0174
# epoch 40 loss=0.0171
# epoch =  40 , representation RI_kmeans =  0.8863 , representation_Acc_kmeans =  0.5605
# epoch 41 loss=0.0169
# epoch 42 loss=0.0170
# epoch 43 loss=0.0168
# epoch 44 loss=0.0167
# epoch 45 loss=0.0165
# epoch 46 loss=0.0165
# epoch 47 loss=0.0166
# epoch 48 loss=0.0163
# epoch 49 loss=0.0163
# epoch 50 loss=0.0162
# epoch =  50 , representation RI_kmeans =  0.8888 , representation_Acc_kmeans =  0.6018
# epoch 51 loss=0.0160
# epoch 52 loss=0.0160
# epoch 53 loss=0.0159
# epoch 54 loss=0.0157
# epoch 55 loss=0.0155
# epoch 56 loss=0.0154
# epoch 57 loss=0.0155
# epoch 58 loss=0.0157
# epoch 59 loss=0.0158
# epoch 60 loss=0.0160
# epoch =  60 , representation RI_kmeans =  0.8924 , representation_Acc_kmeans =  0.6165
# epoch 140 loss=0.0140
# epoch =  140 , representation RI_kmeans =  0.8755 , representation_Acc_kmeans =  0.551
# epoch 141 loss=0.0145
# epoch 142 loss=0.0141
# epoch 143 loss=0.0136
# epoch 144 loss=0.0136
# epoch 145 loss=0.0139
# epoch 146 loss=0.0139
# epoch 147 loss=0.0136
# epoch 148 loss=0.0133
# epoch 149 loss=0.0132
# epoch 150 loss=0.0134
# epoch =  150 , representation RI_kmeans =  0.8817 , representation_Acc_kmeans =  0.5888
# epoch 151 loss=0.0136
# epoch 152 loss=0.0133
# epoch 153 loss=0.0128
# epoch 154 loss=0.0125
# epoch 155 loss=0.0125
# epoch 156 loss=0.0126
# epoch 157 loss=0.0129
# epoch 158 loss=0.0133
# epoch 159 loss=0.0135
# epoch 160 loss=0.0136
# epoch =  160 , representation RI_kmeans =  0.8782 , representation_Acc_kmeans =  0.5726
# epoch 161 loss=0.0133
# epoch 162 loss=0.0130
# epoch 163 loss=0.0129
# epoch 164 loss=0.0129
# epoch 165 loss=0.0130
# epoch 166 loss=0.0131
# epoch 167 loss=0.0130
# epoch 168 loss=0.0128
# epoch 169 loss=0.0127
# epoch 170 loss=0.0126
# epoch =  170 , representation RI_kmeans =  0.8771 , representation_Acc_kmeans =  0.5654
# epoch 171 loss=0.0126
# epoch 172 loss=0.0127
# epoch 173 loss=0.0127
# epoch 174 loss=0.0128
# epoch 175 loss=0.0132
# epoch 176 loss=0.0134
# epoch 177 loss=0.0134
# epoch 178 loss=0.0133
# epoch 179 loss=0.0130
# epoch 180 loss=0.0126
# epoch =  180 , representation RI_kmeans =  0.8779 , representation_Acc_kmeans =  0.5704
# epoch 181 loss=0.0124
# epoch 182 loss=0.0125
# epoch 183 loss=0.0128
# epoch 184 loss=0.0129
# epoch 185 loss=0.0131
# epoch 186 loss=0.0132
# epoch 187 loss=0.0132
# epoch 188 loss=0.0133
# epoch 189 loss=0.0132
# epoch 190 loss=0.0129
# epoch =  190 , representation RI_kmeans =  0.8784 , representation_Acc_kmeans =  0.5697
# epoch 191 loss=0.0125
# epoch 192 loss=0.0124
# epoch 193 loss=0.0125
# epoch 194 loss=0.0127
# epoch 195 loss=0.0130
# epoch 196 loss=0.0130
# epoch 197 loss=0.0127
# epoch 198 loss=0.0125
# epoch 199 loss=0.0124
# epoch 200 loss=0.0124
# epoch =  200 , representation RI_kmeans =  0.8687 , representation_Acc_kmeans =  0.5261
# ******************************
# max_acc =  0.6165
# max_ri =  0.8924
# End training of AE.
# hidden_RI =  0.877 , hidden_Acc =  0.5656
# Row_RI =  0.8809 , Row_Acc =  0.5377

# %%
temp_X = torch.tensor(x[:6000]).to(device)
_, hidden_x = model_part(temp_X)
hidden_RI, hidden_Acc = AccRIkeans(data=hidden_x.data.cpu().numpy(), num_class=10, real_label=y[:6000])
print("hidden_RI = ", hidden_RI, ", hidden_Acc = ", hidden_Acc)
# Out:
# hidden_RI =  0.8659 , hidden_Acc =  0.5182
